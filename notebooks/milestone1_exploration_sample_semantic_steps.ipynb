# %% [markdown]
# # Milestone 1 Exploration and Retrieval Corpus Preparation
#
# This notebook documents the **data exploration and preprocessing** work for Milestone 1 of the Amazon product query assistant project.
#
# For this milestone, we use a **representative sample** from the **Video_Games** category of the Amazon Reviews 2023 dataset.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import pandas as pd

from src.utils import load_jsonl, build_retrieval_text, pick_join_key, save_corpus
from src.bm25 import BM25Retriever
from src.semantic import SemanticRetriever

# %% [markdown]
# ## Load raw files
#
# The project expects these files in `data/raw/`:
#
# - `Video_Games.jsonl`
# - `meta_Video_Games.jsonl`

# %%
reviews_path = Path("../data/raw/Video_Games.jsonl")
meta_path = Path("../data/raw/meta_Video_Games.jsonl")

reviews_df = load_jsonl(reviews_path)
meta_df = load_jsonl(meta_path)

print("Reviews shape:", reviews_df.shape)
print("Metadata shape:", meta_df.shape)
# Out:
# Reviews shape: (4624615, 10)
# Metadata shape: (137269, 16)

# %% [markdown]
# ## Sample review records

# %%
reviews_df.head()
# Out:
#    rating                                              title  \
# 0     4.0                     It’s pretty sexual. Not my fav
# 1     5.0                                   Good. A bit slow
# 2     5.0  ... an order for my kids & they have really en...
# 3     5.0                        Great alt to pro controller
# 4     5.0                                      solid product
#
#                                                 text images        asin  \
# 0  I’m playing on ps5 and it’s interesting.  It’s...     []  B07DJWBYKP
# 1  Nostalgic fun.  A bit slow.  I hope they don’t...     []  B00ZS80PC2
# 2  This was an order for my kids & they have real...     []  B01FEHJYUU
# 3  These work great, They use batteries which is ...     []  B07GXJHRVK
# 4  I would recommend to anyone looking to add jus...     []  B00HUWA45W
#
#   parent_asin                       user_id      timestamp  helpful_vote  \
# 0  B07DK1H3H5  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  1608186804795             0
# 1  B07SRWRH5D  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  1587051114941             1
# 2  B07MFMFW34  AGXVBIUFLFGMVLATYXHJYL4A5Q7Q  1490877431000             0
# 3  B0BCHWZX95  AFTC6ZR5IKNRDG5JCPVNVMU3XV2Q  1577637634017             0
# 4  B00HUWA45W  AFTC6ZR5IKNRDG5JCPVNVMU3XV2Q  1427591932000             0
#
#    verified_purchase
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %% [markdown]
# ## Sample metadata records

# %%
meta_df.head()
# Out:
#   main_category                                              title  \
# 0   Video Games                     Dash 8-300 Professional Add-On
# 1   Video Games                  Phantasmagoria: A Puzzle of Flesh
# 2   Video Games   NBA 2K17 - Early Tip Off Edition - PlayStation 4
# 3   Video Games  Nintendo Selects: The Legend of Zelda Ocarina ...
# 4   Video Games   Thrustmaster Elite Fitness Pack for Nintendo Wii
#
#    average_rating  rating_number  \
# 0             5.0              1
# 1             4.1             18
# 2             4.3            223
# 3             4.9             22
# 4             3.0              3
#
#                                             features  \
# 0  [Features Dash 8-300 and 8-Q300 ('Q' rollout l...
# 1                                       [Windows 95]
# 2  [The #1 rated NBA video game simulation series...
# 3  [Authentic Nintendo Selects: The Legend of Zel...
# 4  [Includes (9) Total Accessories, Pedometer, Wi...
#
#                                          description  price  \
# 0  [The Dash 8-300 Professional Add-On lets you p...   None
# 1                                                 []   None
# 2  [Following the record-breaking launch of NBA 2...   58.0
# 3                                                 []  37.42
# 4  [The Thrustmaster Motion Plus Elite Fitness Pa...   None
#
#                                               images  \
# 0  [{'thumb': 'https://m.media-amazon.com/images/...
# 1  [{'thumb': 'https://m.media-amazon.com/images/...
# 2  [{'thumb': 'https://m.media-amazon.com/images/...
# 3  [{'thumb': 'https://m.media-amazon.com/images/...
# 4  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                               videos           store  \
# 0                                                 []        Aerosoft
# 1                                                 []          Sierra
# 2  [{'title': 'NBA 2K17 - Kobe: Haters vs Players...              2K
# 3                                                 []  Amazon Renewed
# 4                                                 []    THRUSTMASTER
#
#                                           categories  \
# 0                           [Video Games, PC, Games]
# 1                           [Video Games, PC, Games]
# 2                [Video Games, PlayStation 4, Games]
# 3  [Video Games, Legacy Systems, Nintendo Systems...
# 4  [Video Games, Legacy Systems, Nintendo Systems...
#
#                                              details parent_asin  \
# 0  {'Pricing': 'The strikethrough price is the Li...  B000FH0MHO
# 1  {'Best Sellers Rank': {'Video Games': 137612, ...  B00069EVOG
# 2  {'Release date': 'September 16, 2016', 'Best S...  B00Z9TLVK0
# 3  {'Best Sellers Rank': {'Video Games': 51019, '...  B07SZJZV88
# 4  {'Release date': 'November 1, 2009', 'Pricing'...  B002WH4ZJG
#
#   bought_together subtitle author
# 0            None      NaN    NaN
# 1            None      NaN    NaN
# 2            None      NaN    NaN
# 3            None      NaN    NaN
# 4            None      NaN    NaN

# %% [markdown]
# ## Column overview

# %%
print("Review columns:")
print(reviews_df.columns.tolist())

print("\nMetadata columns:")
print(meta_df.columns.tolist())
# Out:
# Review columns:
# ['rating', 'title', 'text', 'images', 'asin', 'parent_asin', 'user_id', 'timestamp', 'helpful_vote', 'verified_purchase']
#
# Metadata columns:
# ['main_category', 'title', 'average_rating', 'rating_number', 'features', 'description', 'price', 'images', 'videos', 'store', 'categories', 'details', 'parent_asin', 'bought_together', 'subtitle', 'author']

# %% [markdown]
# ## Missingness in key fields

# %%
key_cols_reviews = [col for col in ["parent_asin", "asin", "title", "text", "rating"] if col in reviews_df.columns]
key_cols_meta = [col for col in ["parent_asin", "asin", "title", "description", "features", "categories", "price"] if col in meta_df.columns]

print("Missing values in review fields:")
print(reviews_df[key_cols_reviews].isna().sum())

print("\nMissing values in metadata fields:")
print(meta_df[key_cols_meta].isna().sum())
# Out:
# Missing values in review fields:
# parent_asin    0
# asin           0
# title          0
# text           0
# rating         0
# dtype: int64
#
# Missing values in metadata fields:
# parent_asin        0
# title              0
# description        0
# features           0
# categories         0
# price          75261
# dtype: int64

# %% [markdown]
# ## Selection and justification of fields for retrieval
#
# For this project, we build **one retrieval document per review**, enriched with product metadata.
#
# ### Selected fields from reviews
# We use:
#
# - `parent_asin` or `asin` as the join key
# - `title` renamed to `review_title`
# - `text` as the main review content
# - `rating` as useful display metadata
#
# ### Selected fields from metadata
# We use:
#
# - `title` renamed to `product_title`
# - `description`
# - `features`
# - `categories`
# - `price` as optional metadata
#
# ### Justification
# This setup is appropriate because:
#
# 1. the app needs review-level output such as review text and rating
# 2. BM25 and semantic retrieval should search the same document unit
# 3. metadata adds product-level information that may not appear in the review text
# 4. combining review language and metadata language improves retrieval robustness
#
# ### Final retrieval text
# The final `retrieval_text` combines:
#
# - product title
# - categories
# - features
# - description
# - review title
# - review text

# %% [markdown]
# ## Preprocessing decisions
#
# For Milestone 1, we use simple and reproducible preprocessing.
#
# ### Main choices
#
# - lowercase all text
# - remove most punctuation
# - normalize whitespace
# - use whitespace tokenization for BM25
# - use the same cleaned retrieval text for both BM25 and semantic search
#
# ### Why these choices make sense
#
# - lowercasing reduces token variation
# - punctuation removal helps create cleaner BM25 tokens
# - whitespace normalization avoids formatting noise
# - simple tokenization matches the milestone requirement
# - shared document content makes BM25 and semantic search easier to compare fairly

# %% [markdown]
# ## Build the retrieval corpus step by step

# %%
join_key = pick_join_key(reviews_df, meta_df)
print("Join key:", join_key)
# Out:
# Join key: parent_asin

# %%
reviews = reviews_df.copy()
meta = meta_df.copy()

if "title" in reviews.columns:
    reviews = reviews.rename(columns={"title": "review_title"})
if "title" in meta.columns:
    meta = meta.rename(columns={"title": "product_title"})

print("Reviews columns ready.")
print("Meta columns ready.")
# Out:
# Reviews columns ready.
# Meta columns ready.

# %%
meta_cols = [
    col for col in [join_key, "product_title", "description", "features", "categories", "price"]
    if col in meta.columns
]

meta_small = meta[meta_cols].drop_duplicates(subset=[join_key]).copy()

print("Reduced metadata shape:", meta_small.shape)
meta_small.head()
# Out:
# Reduced metadata shape: (137269, 6)
#   parent_asin                                      product_title  \
# 0  B000FH0MHO                     Dash 8-300 Professional Add-On
# 1  B00069EVOG                  Phantasmagoria: A Puzzle of Flesh
# 2  B00Z9TLVK0   NBA 2K17 - Early Tip Off Edition - PlayStation 4
# 3  B07SZJZV88  Nintendo Selects: The Legend of Zelda Ocarina ...
# 4  B002WH4ZJG   Thrustmaster Elite Fitness Pack for Nintendo Wii
#
#                                          description  \
# 0  [The Dash 8-300 Professional Add-On lets you p...
# 1                                                 []
# 2  [Following the record-breaking launch of NBA 2...
# 3                                                 []
# 4  [The Thrustmaster Motion Plus Elite Fitness Pa...
#
#                                             features  \
# 0  [Features Dash 8-300 and 8-Q300 ('Q' rollout l...
# 1                                       [Windows 95]
# 2  [The #1 rated NBA video game simulation series...
# 3  [Authentic Nintendo Selects: The Legend of Zel...
# 4  [Includes (9) Total Accessories, Pedometer, Wi...
#
#                                           categories  price
# 0                           [Video Games, PC, Games]   None
# 1                           [Video Games, PC, Games]   None
# 2                [Video Games, PlayStation 4, Games]   58.0
# 3  [Video Games, Legacy Systems, Nintendo Systems...  37.42
# 4  [Video Games, Legacy Systems, Nintendo Systems...   None

# %%
review_cols = [
    col for col in [join_key, "review_title", "text", "rating"]
    if col in reviews.columns
]

reviews_small = reviews[review_cols].copy()

print("Reduced reviews shape:", reviews_small.shape)
reviews_small.head()
# Out:
# Reduced reviews shape: (4624615, 4)
#   parent_asin                                       review_title  \
# 0  B07DK1H3H5                     It’s pretty sexual. Not my fav
# 1  B07SRWRH5D                                   Good. A bit slow
# 2  B07MFMFW34  ... an order for my kids & they have really en...
# 3  B0BCHWZX95                        Great alt to pro controller
# 4  B00HUWA45W                                      solid product
#
#                                                 text  rating
# 0  I’m playing on ps5 and it’s interesting.  It’s...     4.0
# 1  Nostalgic fun.  A bit slow.  I hope they don’t...     5.0
# 2  This was an order for my kids & they have real...     5.0
# 3  These work great, They use batteries which is ...     5.0
# 4  I would recommend to anyone looking to add jus...     5.0

# %%
reviews_small["text"] = reviews_small["text"].fillna("")
reviews_small = reviews_small[reviews_small["text"].str.len() >= 20].copy()

if "review_title" not in reviews_small.columns:
    reviews_small["review_title"] = ""

print("Filtered reviews shape:", reviews_small.shape)
# Out:
# Filtered reviews shape: (4078697, 4)

# %%
merged = reviews_small.merge(meta_small, on=join_key, how="left")

if "product_title" not in merged.columns:
    merged["product_title"] = ""

print("Merged shape:", merged.shape)
merged.head()
# Out:
# Merged shape: (4078697, 9)
#   parent_asin                                       review_title  \
# 0  B07DK1H3H5                     It’s pretty sexual. Not my fav
# 1  B07SRWRH5D                                   Good. A bit slow
# 2  B07MFMFW34  ... an order for my kids & they have really en...
# 3  B0BCHWZX95                        Great alt to pro controller
# 4  B00HUWA45W                                      solid product
#
#                                                 text  rating  \
# 0  I’m playing on ps5 and it’s interesting.  It’s...     4.0
# 1  Nostalgic fun.  A bit slow.  I hope they don’t...     5.0
# 2  This was an order for my kids & they have real...     5.0
# 3  These work great, They use batteries which is ...     5.0
# 4  I would recommend to anyone looking to add jus...     5.0
#
#                                        product_title  \
# 0    Cyberpunk 2077 - PC [Game Download Code in Box]
# 1          Final Fantasy VII: Remake - PlayStation 4
# 2  Sid Meier’s Civilization VI: Rise and Fall [On...
# 3  PowerA Enhanced Wireless Controller for Ninten...
# 4    KontrolFreek FPS Freek CQC Signature - Xbox One
#
#                                          description  \
# 0  [Cyberpunk 2077 is an open world, an action ad...
# 1  [A spectacular reimagining of one of the most ...
# 2  [Civilization VI is a game about building an e...
# 3  [Play your favorite Nintendo Switch games like...
# 4                                                 []
#
#                                             features  \
# 0  [Become a cyberpunk an urban mercenary equippe...
# 1  [Explore a dark & eclectic world – Dive deep i...
# 2  [Civilization VI: Rise and Fall introduces eig...
# 3  [Bluetooth wireless freedom, Ergonomic design ...
# 4  [Better control = Higher accuracy in FPSs, Mor...
#
#                                           categories  price
# 0                           [Video Games, PC, Games]   None
# 1                [Video Games, PlayStation 4, Games]  25.95
# 2                           [Video Games, PC, Games]  29.99
# 3  [Video Games, Nintendo Switch, Accessories, Co...  67.61
# 4               [Video Games, Xbox One, Accessories]   None

# %% [markdown]
# ## Create a representative sample corpus
#
# The full dataset is large, so this notebook uses a representative sample for the rest of the project.

# %%
SAMPLE_SIZE = 50000

corpus_sample = merged.iloc[:SAMPLE_SIZE].copy()

print("Corpus sample shape:", corpus_sample.shape)
# Out:
# Corpus sample shape: (50000, 9)

# %%
corpus_sample["retrieval_text"] = corpus_sample.apply(build_retrieval_text, axis=1)
corpus_sample = corpus_sample[corpus_sample["retrieval_text"].str.len() > 0].copy()
corpus_sample = corpus_sample.reset_index(drop=True)
corpus_sample["doc_id"] = [f"doc_{i}" for i in range(len(corpus_sample))]

print("Corpus sample after retrieval text:", corpus_sample.shape)
# Out:
# Corpus sample after retrieval text: (50000, 11)

# %%
keep_cols = [
    col for col in [
        "doc_id",
        join_key,
        "product_title",
        "review_title",
        "text",
        "rating",
        "price",
        "retrieval_text",
        "description",
        "features",
        "categories",
    ]
    if col in corpus_sample.columns
]

corpus_sample = corpus_sample[keep_cols].copy()
corpus_sample.head()
# Out:
#   doc_id parent_asin                                      product_title  \
# 0  doc_0  B07DK1H3H5    Cyberpunk 2077 - PC [Game Download Code in Box]
# 1  doc_1  B07SRWRH5D          Final Fantasy VII: Remake - PlayStation 4
# 2  doc_2  B07MFMFW34  Sid Meier’s Civilization VI: Rise and Fall [On...
# 3  doc_3  B0BCHWZX95  PowerA Enhanced Wireless Controller for Ninten...
# 4  doc_4  B00HUWA45W    KontrolFreek FPS Freek CQC Signature - Xbox One
#
#                                         review_title  \
# 0                     It’s pretty sexual. Not my fav
# 1                                   Good. A bit slow
# 2  ... an order for my kids & they have really en...
# 3                        Great alt to pro controller
# 4                                      solid product
#
#                                                 text  rating  price  \
# 0  I’m playing on ps5 and it’s interesting.  It’s...     4.0   None
# 1  Nostalgic fun.  A bit slow.  I hope they don’t...     5.0  25.95
# 2  This was an order for my kids & they have real...     5.0  29.99
# 3  These work great, They use batteries which is ...     5.0  67.61
# 4  I would recommend to anyone looking to add jus...     5.0   None
#
#                                       retrieval_text  \
# 0  cyberpunk 2077 pc game download code in box vi...
# 1  final fantasy vii remake playstation 4 video g...
# 2  sid meier s civilization vi rise and fall onli...
# 3  powera enhanced wireless controller for ninten...
# 4  kontrolfreek fps freek cqc signature xbox one ...
#
#                                          description  \
# 0  [Cyberpunk 2077 is an open world, an action ad...
# 1  [A spectacular reimagining of one of the most ...
# 2  [Civilization VI is a game about building an e...
# 3  [Play your favorite Nintendo Switch games like...
# 4                                                 []
#
#                                             features  \
# 0  [Become a cyberpunk an urban mercenary equippe...
# 1  [Explore a dark & eclectic world – Dive deep i...
# 2  [Civilization VI: Rise and Fall introduces eig...
# 3  [Bluetooth wireless freedom, Ergonomic design ...
# 4  [Better control = Higher accuracy in FPSs, Mor...
#
#                                           categories
# 0                           [Video Games, PC, Games]
# 1                [Video Games, PlayStation 4, Games]
# 2                           [Video Games, PC, Games]
# 3  [Video Games, Nintendo Switch, Accessories, Co...
# 4               [Video Games, Xbox One, Accessories]

# %%
processed_dir = Path("../data/processed")
processed_dir.mkdir(parents=True, exist_ok=True)

save_corpus(corpus_sample, processed_dir / "video_games_corpus_sample.parquet")
print("Saved sample corpus to ../data/processed/video_games_corpus_sample.parquet")
# Out:
# Saved sample corpus to ../data/processed/video_games_corpus_sample.parquet

# %% [markdown]
# ## Step 2: BM25 Search on the representative sample
#
# This section builds the BM25 retriever on the sample corpus and saves the BM25 artifacts locally.

# %%
bm25 = BM25Retriever(corpus_sample)
bm25.save(
    processed_dir / "bm25_sample_index.pkl",
    processed_dir / "bm25_sample_tokens.pkl",
)

print("Saved BM25 sample artifacts:")
print("- ../data/processed/bm25_sample_index.pkl")
print("- ../data/processed/bm25_sample_tokens.pkl")
# Out:
# Saved BM25 sample artifacts:
# - ../data/processed/bm25_sample_index.pkl
# - ../data/processed/bm25_sample_tokens.pkl

# %%
bm25_query = "best racing game with fun tracks"
bm25_results = bm25.search(bm25_query, top_k=5)

print("BM25 query:", bm25_query)
bm25_results[["product_title", "review_title", "rating", "bm25_score"]].head()
# Out:
# BM25 query: best racing game with fun tracks
#                                        product_title  \
# 0            LittleBigPlanet Karting - Playstation 3
# 1            LittleBigPlanet Karting - Playstation 3
# 2            LittleBigPlanet Karting - Playstation 3
# 3            LittleBigPlanet Karting - Playstation 3
# 4  Champion Jockey: G1 Jockey and Gallop Racer - ...
#
#                                       review_title  rating  bm25_score
# 0                            Fun game for everyone     5.0   24.851332
# 1                                Seller came thru!     5.0   24.825243
# 2                                             Fun!     5.0   24.802589
# 3  A present for my adult daughter on her birthday     5.0   24.638145
# 4                                        Two Stars     2.0   24.388155

# %% [markdown]
# ## Step 3: Semantic Search on the representative sample
#
# The semantic step can still be slow, so this notebook breaks it into smaller parts:
#
# 1. create a smaller semantic subset
# 2. inspect the text that will be embedded
# 3. initialize the semantic retriever
# 4. build the FAISS index
# 5. save the semantic artifacts
# 6. run a query and save results
#
# If it still feels slow, reduce `SEMANTIC_SAMPLE_SIZE`.

# %%
SEMANTIC_SAMPLE_SIZE = 1000

semantic_sample = corpus_sample.iloc[:SEMANTIC_SAMPLE_SIZE].copy()

print("Semantic sample shape:", semantic_sample.shape)
# Out:
# Semantic sample shape: (1000, 11)

# %%
semantic_sample[["product_title", "review_title", "retrieval_text"]].head(3)
# Out:
#                                        product_title  \
# 0    Cyberpunk 2077 - PC [Game Download Code in Box]
# 1          Final Fantasy VII: Remake - PlayStation 4
# 2  Sid Meier’s Civilization VI: Rise and Fall [On...
#
#                                         review_title  \
# 0                     It’s pretty sexual. Not my fav
# 1                                   Good. A bit slow
# 2  ... an order for my kids & they have really en...
#
#                                       retrieval_text
# 0  cyberpunk 2077 pc game download code in box vi...
# 1  final fantasy vii remake playstation 4 video g...
# 2  sid meier s civilization vi rise and fall onli...

# %%
semantic = SemanticRetriever(semantic_sample)
print("Semantic retriever initialized.")
# Out:
# /Users/lukeni/miniforge3/envs/dsci575-ml/lib/python3.11/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Semantic retriever initialized.

# %%
# This is the slowest step.
# Reduce SEMANTIC_SAMPLE_SIZE above if needed.

semantic.build_index()
print("Semantic FAISS index built.")
# Out:
# Semantic FAISS index built.

# %%
semantic.save(
    processed_dir / "faiss_sample.index",
    processed_dir / "semantic_sample_metadata.pkl",
)

print("Saved semantic sample artifacts:")
print("- ../data/processed/faiss_sample.index")
print("- ../data/processed/semantic_sample_metadata.pkl")
# Out:
# Saved semantic sample artifacts:
# - ../data/processed/faiss_sample.index
# - ../data/processed/semantic_sample_metadata.pkl

# %%
semantic_query = "story-rich scary game with dark atmosphere"
semantic_results = semantic.search(semantic_query, top_k=5)

print("Semantic query:", semantic_query)
semantic_results[["product_title", "review_title", "rating", "semantic_score"]].head()
# Out:
# Semantic query: story-rich scary game with dark atmosphere
#                                        product_title  \
# 0  Among the Sleep: Enhanced Edition - Nintendo S...
# 1                      Scratches: Directors Cut - PC
# 2                               Bad Mojo: Redux - PC
# 3                 Broken Sword: Sleeping Dragon - PC
# 4                   Silent Hill: Downpour - Xbox 360
#
#                                         review_title  rating  semantic_score
# 0                                   Hated this game.     1.0        0.557222
# 1         A haunting vacation you'll never forget...     4.0        0.492031
# 2  A gritty, edgy homage to Kafka and Lynch that ...     5.0        0.487693
# 3                 George and Nico are back in style!     5.0        0.485437
# 4                                  Never finished it     3.0        0.469734

# %% [markdown]
# ## Save sample retrieval outputs
#
# These CSV files make it easy to inspect and share example outputs from both retrieval methods.

# %%
bm25_results.to_csv(processed_dir / "bm25_sample_results.csv", index=False)
semantic_results.to_csv(processed_dir / "semantic_sample_results.csv", index=False)

print("Saved:")
print("- ../data/processed/bm25_sample_results.csv")
print("- ../data/processed/semantic_sample_results.csv")
# Out:
# Saved:
# - ../data/processed/bm25_sample_results.csv
# - ../data/processed/semantic_sample_results.csv

# %% [markdown]
# ## Summary
#
# This notebook now covers:
#
# - Step 1: data exploration and preprocessing
# - Step 2: BM25 search on the representative sample
# - Step 3: semantic search on a smaller semantic subset
#
# Saved sample outputs include:
#
# - `video_games_corpus_sample.parquet`
# - `bm25_sample_index.pkl`
# - `bm25_sample_tokens.pkl`
# - `faiss_sample.index`
# - `semantic_sample_metadata.pkl`
# - `bm25_sample_results.csv`
# - `semantic_sample_results.csv`
#
# If semantic search is still slow, reduce `SEMANTIC_SAMPLE_SIZE` and rerun only the Step 3 cells.
